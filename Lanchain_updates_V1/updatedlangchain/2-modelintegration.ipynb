# %% [markdown]
# ### Models Integration With OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots are fascinating creatures, and their ability to "talk" (or more accurately, mimic human speech) is one of their most well-known traits. It\'s not fully understood why they do it, but scientists have several strong theories that point to a combination of biological, social, and cognitive factors:\n\n1.  **Vocal Learning Ability:**\n    *   **Specialized Anatomy:** Parrots possess a highly flexible vocal organ called the **syrinx** (their equivalent of a voice box). This allows them to produce a wide range of sounds, pitches, and tones.\n    *   **Unique Brain Structure:** Unlike most animals whose vocalizations are largely innate, parrots have specialized brain regions dedicated to vocal learning. These "vocal learning centers" allow them to acquire and produce new sounds throughout their lives, much like humans, songbirds, and hummingbirds.\n\n2.  **Highly Social Animals:**\n    *   **Flock Cohesion:** Parrots are extremely social and live in complex flocks in the wild. Communication is vital for maintaining flock cohesion, warning of predators, locating food, identifying individuals, and finding mates.\n    *   **Mimicry as a Social Tool:** In their natural habitat, parrots mimic the calls of other parrots in their flock. This helps them identify as part of the group, bond with others, and learn important information. It\'s a way of "fitting in" and communicating within their social structure.\n\n3.  **Intelligence and Cognitive Ability:**\n    *   Parrots are highly intelligent birds, capable of problem-solving and understanding concepts. This cognitive ability allows them to not just mimic sounds, but often to associate those sounds with specific contexts or meanings. For example, a parrot might say "hello" when someone enters the room or "goodbye" when they leave.\n\n4.  **In Captivity: Bonding and Attention:**\n    *   **Humans as their "Flock":** When parrots are kept as pets, humans become their primary social group. They use their natural tendency for vocal mimicry to try and communicate with their human companions.\n    *   **Seeking Attention:** Parrots are intelligent and can quickly learn that mimicking human speech often garners attention, treats, or praise from their owners. This positive reinforcement encourages them to talk more.\n    *   **Boredom/Stimulation:** Talking can also be a form of self-stimulation or a way to engage with their environment, especially if they are bored or seeking interaction.\n\nIn summary, parrots talk because they possess a unique biological capacity for vocal learning, are highly social animals that use vocalizations for communication and bonding, and are intelligent enough to associate sounds with meaning. In a human environment, they apply these natural abilities to interact and bond with their human "flock."'

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI



model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots talk primarily because they are **highly intelligent and social creatures** that have evolved to communicate effectively within their flocks. Their ability to mimic sounds, including human speech, is a fascinating byproduct of this evolutionary drive.\n\nHere\'s a breakdown of the main reasons:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Dynamics:** Parrots are flock animals. In the wild, they use a variety of vocalizations to stay in contact with their group, warn of danger, find food, and maintain social bonds. Mimicking sounds, including other birds\' calls, helps them integrate into the flock and understand group signals.\n* **Strengthening Relationships:** For parrots, vocal interaction is a crucial part of their social life. Mimicking sounds can be a way to show affiliation, express affection, or simply participate in the group\'s "conversation."\n\n**2. Intelligence and Cognitive Abilities:**\n\n* **Advanced Vocal Learning:** Parrots are among the few bird species (along with songbirds and hummingbirds) that exhibit advanced vocal learning. This means they can learn and reproduce new sounds throughout their lives, rather than having a fixed repertoire.\n* **Problem-Solving and Understanding:** While they might not "understand" the meaning of human words in the same way we do, many parrots demonstrate a remarkable ability to associate sounds with specific objects, actions, or contexts. They can learn to request things, respond to commands, and even engage in simple conversations.\n* **Cognitive Stimulation:** The ability to learn and use new sounds is likely a form of cognitive stimulation for them. It keeps their minds engaged and provides a way to interact with their environment.\n\n**3. Mimicry as a Survival Tool (in some contexts):**\n\n* **Camouflage and Integration:** In the wild, mimicking the sounds of their environment or other animals can help them blend in and avoid predators.\n* **Social Advantage:** Being able to mimic the calls of other flock members can give them an advantage in social standing or access to resources.\n\n**4. In Captivity: A Different Environment, Similar Instincts:**\n\n* **Attraction to Novel Sounds:** In a human household, parrots are exposed to a constant stream of new and interesting sounds. Their innate drive to learn and mimic leads them to pick up on these sounds, especially human speech, which is often repetitive and patterned.\n* **Attention and Interaction:** Parrots are intelligent and often seek attention from their human companions. Mimicking sounds, especially those that elicit a positive response, becomes a way to get noticed and interact. They learn that saying certain words or phrases can lead to treats, praise, or play.\n* **Bonding with Owners:** For many pet parrots, learning to "talk" is a significant part of their bond with their human family. It\'s a way for them to communicate their needs and desires and to feel like a part of the family unit.\n\n**It\'s important to note that:**\n\n* **Not all parrots talk:** While many species have the capacity, some are more inclined to mimic than others. African Greys, Amazons, and some cockatoos are particularly renowned for their talking abilities.\n* **"Talking" is not the same as human language:** Parrots don\'t possess the same cognitive structures or understanding of abstract concepts as humans. Their "speech" is primarily learned mimicry, though some can learn to associate words with meanings.\n* **Motivation varies:** A parrot\'s willingness to talk can depend on its personality, its environment, and its relationship with its owner.\n\nIn essence, parrots talk because they are highly evolved communicators with a remarkable capacity for vocal learning. Their intelligence, social nature, and ability to adapt to their surroundings all contribute to this fascinating behavior.'

# %% [markdown]
# ### GROQ MODEL Integration

# %%
import os
from langchain.chat_models import init_chat_model

model = init_chat_model("groq:llama-3.1-8b-instant")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# "Parrots are known for their ability to mimic human speech and other sounds, and it's a complex phenomenon that has fascinated humans for centuries. There are several reasons why parrots talk:\n\n1. **Social Learning**: Parrots are highly social birds that live in flocks in the wild. They learn by observing and imitating others, including their parents and other birds. This social learning mechanism helps them acquire vocalizations, including human speech.\n2. **Mimicry**: Parrots have a unique anatomy that allows them to produce a wide range of sounds, including human speech. They have a large syrinx, a vocal organ located at the base of the trachea, which is made up of two pairs of cartilaginous rings. This allows them to produce complex sounds and mimic other birds, animals, and even mechanical noises.\n3. **Attention and Affection**: Parrots may talk to get attention or affection from their owners. They may associate speech with rewards, such as food or praise, which motivates them to continue vocalizing.\n4. **Communication**: Parrots use vocalizations to communicate with each other, including warning calls, courtship displays, and contact calls. Some parrots may talk to communicate with their owners or to initiate interaction.\n5. **Cognitive Ability**: Parrots are highly intelligent birds that possess advanced cognitive abilities, including memory, problem-solving, and learning. Their ability to talk is thought to be linked to their cognitive capacity, which allows them to understand and reproduce complex sounds.\n\nSome popular theories about why parrots talk include:\n\n* **Evolutionary Advantage**: One theory is that parrots' ability to mimic human speech may have evolved as a way to communicate with humans and gain an advantage in terms of food or protection.\n* **Brain Structure**: Research suggests that parrots' brains may be more similar to humans' brains than other bird brains, which could contribute to their ability to talk.\n* **Social Bonding**: Parrots may talk to strengthen their bond with their owners or to establish a connection with them.\n\nOverall, the reasons why parrots talk are complex and multifaceted, and it's likely that a combination of these factors contributes to their ability to mimic human speech."

# %%
import os
from langchain_groq import ChatGroq



model = ChatGroq(model="llama-3.1-8b-instant")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# "Parrots are known for their ability to mimic human speech and other sounds, and it's a complex phenomenon that has fascinated people for centuries. While we can't know for certain why individual parrots talk, research has shed some light on the underlying reasons. Here are some possible explanations:\n\n1. **Communication:** Parrots use vocalizations to communicate with each other, just like humans do. They may talk to convey information, express emotions, or signal intentions. By mimicking human speech, parrots may be trying to communicate with their human caregivers or other parrots.\n2. **Social bonding:** Parrots are highly social animals that thrive on interaction with their flock. Talking may be a way for them to bond with their human caregivers or other parrots, as they associate the human voice with food, attention, and affection.\n3. **Learning and memory:** Parrots are renowned for their exceptional learning and memory abilities. They can learn to mimic complex sounds, including human speech, through repetition and practice. Talking may be a way for them to exercise their cognitive abilities and demonstrate their intelligence.\n4. **Social status:** In some parrot species, vocalizations are used to establish dominance or hierarchy. Talking may be a way for a parrot to assert its dominance or establish its social status within the flock.\n5. **Environmental stimulation:** Parrots may talk simply because they have the ability and the opportunity to do so. In a stimulating environment with plenty of attention and interaction, they may be more likely to vocalize and mimic human speech.\n6. **Imprinting:** Young parrots, particularly those raised in captivity, may imprint on their human caregivers and learn to mimic their speech patterns. This is a natural process in parrots, where they form a strong bond with their caregivers and learn to associate them with food, shelter, and protection.\n\nIt's essential to note that not all parrots talk, and the ability to mimic human speech is more common in certain species, such as African Greys, Amazon parrots, and Macaws. Additionally, talking parrots may not necessarily understand the meaning of their own words, as their vocalizations are primarily driven by association and conditioning rather than true comprehension."

# %% [markdown]
# ### Streaming And Batch
#
# ### Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses.
# Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) has revolutionized the world in various aspects, transforming the way we live, work, and interact. AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. Machine learning algorithms enable AI systems to learn from data, identify patterns, and make predictions or recommendations. This has led to significant advancements in industries like healthcare, finance, and transportation. AI-powered chatbots and virtual assistants have improved customer service, while AI-driven analytics has enhanced business decision-making. Additionally, AI has enabled the development of autonomous vehicles, drones, and robotics, which are transforming manufacturing, logistics, and other sectors. However, the increasing dependence on AI has also raised concerns about job displacement, bias in decision-making, and the potential risks of AI systems becoming uncontrollable. Despite these challenges, researchers and developers continue to work towards creating more sophisticated and responsible AI systems that can augment human capabilities while minimizing its limitations. As AI continues to evolve, its impact on society will be significant, and it is crucial to address the ethical and regulatory implications of its development and deployment.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 231, 'prompt_tokens': 45, 'total_tokens': 276, 'completion_time': 0.423896508, 'completion_tokens_details': None, 'prompt_time': 0.002265918, 'prompt_tokens_details': None, 'queue_time': 0.045777231, 'total_time': 0.426162426}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d0650-37fb-7480-b5a8-116a5d25c512-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 231, 'total_tokens': 276})

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Art|ificial| Intelligence| (|AI|)| has| become| an| integral| part| of| modern| technology|,| revolution|izing| the| way| we| live| and| interact| with| the| world| around| us|.| At| its| core|,| AI| refers| to| the| development| of| computer| systems| that| can| perform| tasks| that| would| typically| require| human| intelligence|,| such| as| learning|,| problem|-solving|,| and| decision|-making|.| From| virtual| assistants| like| Siri| and| Alexa| to| self|-driving| cars| and| personalized| product| recommendations|,| AI| is| increasingly| being| used| to| improve| efficiency|,| accuracy|,| and| user| experience|.| Machine| learning| algorithms|,| a| key| component| of| AI|,| enable| systems| to| learn| from| data| and| improve| their| performance| over| time|,| allowing| them| to| adapt| to| new| situations| and| environments|.| As| AI| technology| continues| to| advance|,| we| can| expect| to| see| even| more| innovative| applications|,| such| as| healthcare| diagnosis| and| personalized| medicine|,| financial| forecasting| and| risk| management|,| and| intelligent| transportation| systems|.| While| AI| holds| tremendous| promise|,| it| also| raises| important| questions| about| ethics|,| accountability|,| and| the| potential| risks| of| relying| on| machines| to| make| decisions| on| our| behalf|.| As| we| navigate| this| rapidly| evolving| landscape|,| it|'s| essential| to| prioritize| responsible| AI| development| and| ensure| that| its| benefits| are| shared| equ|itably| by| all|.|||

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content="Parrots have colorful feathers due to a combination of genetic and environmental factors, primarily driven by their evolution and adaptation to their surroundings. Here are some reasons why parrots have vibrant plumage:\n\n1. **Mating and courtship**: Bright colors serve as visual signals to attract mates, display dominance, and establish social status within their flock. By showcasing their vibrant feathers, parrots can signal their health, high social status, and genetic quality to potential partners.\n2. **Territorial defense**: Parrots use their bright plumage to deter predators and competitors from entering their territory. The visual display of colorful feathers can intimidate potential intruders and help protect their food sources and nesting sites.\n3. **Communication**: Colorful feathers help parrots communicate with each other through visual displays, such as flashing, posturing, or preening. These displays convey information about an individual's identity, status, and intentions.\n4. **Environmental adaptations**: Parrots living in tropical or subtropical regions often have bright, contrasting colors that help them blend in with their surroundings. In these environments, bright colors can aid in camouflage, making it easier for parrots to hide from predators or sneak up on prey.\n5. **Evolutionary pressures**: Parrots have evolved to occupy a wide range of ecological niches, from forests to grasslands, and from sea coasts to mountains. The development of bright, colorful feathers has likely been driven by the selective pressures of these diverse environments.\n6. **Pigmentation and melanin**: Parrots' colorful feathers are a result of the presence of pigments such as carotenoids, melanin, and porphyrins. These pigments are responsible for the production of bright colors, including yellows, oranges, reds, and blues.\n7. **Diet**: In some cases, parrots' diet may influence the intensity or shade of their colors. For example, some parrots that consume a diet rich in carotenoids may develop more intense yellow or orange hues.\n\nIn summary, parrots' colorful feathers are a result of a combination of genetic and environmental factors, including mating, territorial defense, communication, environmental adaptations, evolutionary pressures, pigmentation, and diet.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 449, 'prompt_tokens': 43, 'total_tokens': 492, 'completion_time': 0.740123271, 'completion_tokens_details': None, 'prompt_time': 0.003018664, 'prompt_tokens_details': None, 'queue_time': 0.046567895, 'total_time': 0.743141935}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d0653-10a4-7eb1-91fe-eb6717b1124a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 449, 'total_tokens': 492})

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Par|rots| have| colorful| feathers| due| to| a| combination| of| factors|.| Here| are| some| reasons|:
#
# |1|.| **|Communication| and| Expression|**:| Color|ful| feathers| help| par|rots| to| communicate| with| each| other|,| express| their| emotions|,| and| establish| their| identity|.| Different| colors| and| patterns| can| convey| different| messages|,| such| as| attraction|,| aggression|,| or| warning| signals|.
#
# |2|.| **|M|ating| and| At|traction|**:| Bright| colors| can| play| a| crucial| role| in| attracting| a| mate|.| Male| par|rots| often| display| their| most| vibrant| colors| to| impress| potential| partners|,| while| females| may| choose| a| mate| based| on| the| intensity| and| quality| of| his| plum|age|.
#
# |3|.| **|Social| Status|**:| In| some| par|rot| species|,| the| intensity| and| quality| of| coloring| can| indicate| social| status| or| dominance|.| Domin|ant| individuals| may| have| brighter| or| more| vibrant| feathers|,| which| can| intimidate| or| attract| subordinate| birds|.
#
# |4|.| **|Cam|ouflage| and| Warning|**:| While| it| may| seem| counter|int|uitive|,| some| par|rots| have| evolved| to| display| bright| colors| in| specific| contexts| to| warn| potential| predators| or| competitors| of| their| toxicity| or| dist|ast|eful|ness|.| For| example|,| some| par|rots| have| brightly| colored| feathers| that| may| signal| to| predators| that| they| are| poisonous| or| un|pal|atable|.
#
# |5|.| **|Ev|olution|ary| Adapt|ation|**:| Color|ful| feathers| can| also| serve| as| a| visual| signal| to| attract| food|,| such| as| n|ectar| or| fruit|,| which| can| be| an| important| source| of| nutrition| for| par|rots|.
#
# |6|.| **|P|ig|mentation| and| Mel|an|in|**:| The| production| of| melan|in|,| a| pigment| responsible| for| color|,| is| influenced| by| genetics| and| environmental| factors|.| Par|rots| have| a| high| concentration| of| melan|in|,| which| is| responsible| for| their| vibrant| colors|.
#
# |In| summary|,| par|rots|'| colorful| feathers| serve| multiple| purposes|,| including| communication|,| mating|,| social| status|,| camouflage|,| warning|,| and| evolutionary| adaptation|.|||

# %% [markdown]
# #### Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots' colorful feathers serve several purposes:\n\n1. **Attracting mates**: Bright colors help parrots attract potential mates and showcase their health and genetic quality. Males often display their most vibrant plumage to impress females.\n2. **Communication**: Colors play a significant role in parrot communication, helping them convey emotions, intentions, and status. For example, a brightly colored parrot may signal aggression or dominance.\n3. **Camouflage and protection**: Some parrot species have colors that help them blend in with their surroundings, making it easier to hide from predators or sneak up on food. Others may display warning colors to deter predators.\n4. **Thermoregulation**: The color and texture of parrot feathers can help regulate their body temperature. Darker colors absorb heat, while lighter colors reflect it.\n5. **Social status**: In some parrot species, the intensity and vibrancy of an individual's coloration can indicate its social status within the flock.\n6. **Mimicry and display**: Parrots use their colorful feathers to mimic other animals, like butterflies or birds of prey, which helps them practice their mimicry skills and display their creativity.\n7. **Evolutionary adaptation**: The evolution of colorful feathers in parrots might be linked to their diet, habitat, or other environmental factors. For example, some parrots that live in areas with low light levels may have evolved brighter colors to compensate for the lack of light.\n\nThese purposes are not mutually exclusive, and parrots' colorful feathers likely serve a combination of these functions. The exact reasons may vary depending on the species, habitat, and social context." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 334, 'prompt_tokens': 43, 'total_tokens': 377, 'completion_time': 0.507836487, 'completion_tokens_details': None, 'prompt_time': 0.002137358, 'prompt_tokens_details': None, 'queue_time': 0.047129182, 'total_time': 0.509973845}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d0655-97a3-7531-8edc-8dc549dd2b15-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 334, 'total_tokens': 377}
# content='Airplanes fly due to the principles of aerodynamics, which is the interaction between air and solid objects. The four main forces involved in flight are:\n\n1. **Lift**: This is the upward force that opposes the weight of the plane and keeps it flying. Lift is created by the wings, which are designed to produce a difference in air pressure above and below the wing. As the plane moves forward, the air flows over and under the curved surface of the wing, creating an area of lower pressure above the wing and an area of higher pressure below it. This pressure difference creates an upward force, or lift, that counteracts the weight of the plane.\n\n2. **Weight**: This is the downward force that is the combined weight of the plane, passengers, cargo, and fuel. The weight of the plane is a constant force that works against the lift, trying to pull the plane down.\n\n3. **Thrust**: This is the forward force that propels the plane through the air. Thrust is created by the plane\'s engines, which produce a stream of high-speed air that exits the back of the plane. As this air exits, it creates a forward force that propels the plane forward.\n\n4. **Drag**: This is the backward force that opposes the motion of the plane. Drag is created by air resistance, which slows down the plane as it moves through the air.\n\nFor an airplane to fly, the lift must be greater than the weight, and the thrust must be greater than the drag. This is known as the "four forces of flight."\n\nHere\'s a step-by-step explanation of how an airplane flies:\n\n1. The plane\'s engines produce thrust, propelling the plane forward.\n2. As the plane moves forward, the air flows over and under the curved surface of the wing, creating a difference in air pressure.\n3. The wing produces lift, opposing the weight of the plane.\n4. The lift and thrust forces work together to counteract the weight and drag forces.\n5. As the plane continues to move forward, the lift and thrust forces balance out, allowing the plane to fly steadily.\n\nThe design of the wing, including its shape, size, and angle of attack, plays a crucial role in creating lift. The wing is typically curved on top and flat on the bottom, which creates a difference in air pressure above and below the wing. The angle of attack, or the angle between the wing and the oncoming airflow, also affects the amount of lift produced.\n\nIn summary, airplanes fly due to the interaction between the four forces of flight: lift, weight, thrust, and drag. The wing is designed to produce lift, which counteracts the weight of the plane, while the engines produce thrust, which propels the plane forward.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 562, 'prompt_tokens': 40, 'total_tokens': 602, 'completion_time': 0.691024421, 'completion_tokens_details': None, 'prompt_time': 0.002282407, 'prompt_tokens_details': None, 'queue_time': 0.047296483, 'total_time': 0.693306828}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d0655-97ad-7ec3-a59e-e5ee782c7804-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 562, 'total_tokens': 602}
# content="Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform computations. It's a fundamentally different approach to computing compared to classical computers, which are based on bits and binary code.\n\n**Classical Computing vs. Quantum Computing:**\n\nIn a classical computer, information is represented as bits, which can have a value of either 0 or 1. The processing of information is based on logical operations, such as AND, OR, and NOT, which are executed sequentially. This sequential processing is the foundation of classical computing.\n\nIn contrast, quantum computing uses quantum bits or qubits, which can exist in multiple states simultaneously. Qubits can represent not just 0 or 1, but also any linear combination of 0 and 1, like 0, 1, or a mixture of both (known as a superposition). This property of qubits allows quantum computers to process vast amounts of information in parallel, making them incredibly powerful for certain types of calculations.\n\n**Key Principles of Quantum Computing:**\n\n1. **Superposition**: Qubits can exist in multiple states at the same time, allowing for parallel processing.\n2. **Entanglement**: Qubits can be connected in a way that their properties are correlated, enabling faster-than-light communication and enhanced computation.\n3. **Quantum measurement**: When a qubit is measured, its state collapses to a single value, but the measurement itself can be used to extract information about the qubit's state.\n4. **Quantum gates**: Quantum computers use quantum gates, which are the quantum equivalent of logic gates, to manipulate qubits and perform calculations.\n\n**Applications of Quantum Computing:**\n\n1. **Cryptography**: Quantum computers can break certain classical encryption algorithms, but they can also be used to create unbreakable quantum encryption methods.\n2. **Optimization**: Quantum computers can quickly find the optimal solution to complex optimization problems, such as scheduling, logistics, and financial modeling.\n3. **Simulation**: Quantum computers can simulate complex systems, such as molecules and materials, to help develop new materials and medicines.\n4. **Machine learning**: Quantum computers can speed up certain machine learning algorithms, enabling faster and more accurate predictions.\n\n**Challenges and Limitations:**\n\n1. **Error correction**: Quantum computers are prone to errors due to the fragile nature of qubits. Developing robust error correction methods is essential for large-scale quantum computing.\n2. **Scalability**: As the number of qubits increases, the complexity of the quantum computer's control system grows exponentially.\n3. **Noise and interference**: Quantum computers are sensitive to noise and interference, which can cause errors and limit their performance.\n\n**Current Status:**\n\nQuantum computing is still in its early stages, but significant progress has been made in recent years. Companies like Google, IBM, and Microsoft are actively developing quantum computing technologies, and several startups are working on quantum software and applications. Governments and research institutions are also investing heavily in quantum computing research.\n\nWhile quantum computing holds great promise, it's still a developing field with many challenges to overcome. However, the potential benefits of quantum computing make it an exciting area of research and innovation." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 639, 'prompt_tokens': 40, 'total_tokens': 679, 'completion_time': 1.061400875, 'completion_tokens_details': None, 'prompt_time': 0.00184226, 'prompt_tokens_details': None, 'queue_time': 0.04776803, 'total_time': 1.063243135}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d0655-97b2-76b3-b38f-b7c886054113-0' tool_cal ...

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots have colorful feathers due to a combination of factors, including genetics, evolution, and their environment. Here are some reasons why parrots have such vibrant plumage:\n\n1. **Attracting a mate**: Bright colors are often used by parrots to attract potential mates. Males with more striking plumage are often more attractive to females, increasing their chances of successful breeding and passing on their genes to their offspring.\n2. **Communication**: Colorful feathers help parrots communicate with each other. Different species have unique color patterns that can signal aggression, courtship, or other social behaviors.\n3. **Camouflage**: While it may seem counterintuitive, some parrots have color patterns that help them blend in with their surroundings. For example, a parrot with a mottled brown and green plumage may be less visible in a forest habitat.\n4. **Social status**: In some parrot species, the brightness and pattern of an individual's feathers can indicate its social status within the group. Dominant birds may have more vibrant plumage, while subordinate birds may have duller colors.\n5. **Environmental adaptations**: Parrots living in areas with high levels of sunlight, such as tropical regions, may develop more intense colors to help them reflect excess heat and protect themselves from the sun.\n6. **Evolutionary history**: Parrots have been around for millions of years, and their colorful feathers may have evolved as a result of natural selection. Over time, birds with more vibrant plumage may have been more successful at attracting mates, defending territories, or avoiding predators.\n\nOverall, the colorful feathers of parrots are a remarkable example of the complex interactions between genetics, environment, and behavior in the natural world.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 349, 'prompt_tokens': 43, 'total_tokens': 392, 'completion_time': 0.498423563, 'completion_tokens_details': None, 'prompt_time': 0.002606431, 'prompt_tokens_details': None, 'queue_time': 0.046932739, 'total_time': 0.501029994}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d0655-ed3e-73c1-90e2-ee7684f2c088-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 349, 'total_tokens': 392}),
#  AIMessage(content="Airplanes fly by using the principles of aerodynamics, which is the study of the interaction between air and solid objects. Here's a simplified explanation of the four main forces that allow an airplane to fly:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the plane and keeps it flying. It's created by the wings, which are designed to produce a difference in air pressure above and below the wing. As the plane moves forward, the air flowing over the curved surface of the wing must travel faster than the air flowing along the flat surface below. This creates a pressure difference, with lower pressure above the wing and higher pressure below. The resulting lift force counteracts the weight of the plane.\n2. **Weight**: Weight is the downward force that pulls the plane towards the ground. It's the combined weight of the plane, passengers, cargo, and fuel.\n3. **Thrust**: Thrust is the forward force that propels the plane through the air. It's created by the plane's engines, which produce a stream of high-speed air that exits the back of the plane. The thrust force counteracts the drag force (more on that below).\n4. **Drag**: Drag is the backward force that opposes the motion of the plane. It's created by air resistance, which slows down the plane as it moves through the air.\n\nTo generate lift, an airplane must:\n\n* Travel at a sufficient speed (above stall speed)\n* Have a wing with a curved upper surface and a flat lower surface\n* Have a sufficient angle of attack (the angle between the wing and the oncoming airflow)\n\nWhen an airplane is in flight, the four forces are in balance:\n\n* Lift (up) = Weight (down)\n* Thrust (forward) = Drag (backward)\n\nAs the plane moves forward, the lift force counteracts the weight, keeping the plane flying. The thrust force counteracts the drag, propelling the plane through the air.\n\nIn summary, airplanes fly by using the principles of aerodynamics to create lift, which counteracts weight, and thrust, which counteracts drag. The four forces work together to allow the plane to take off, fly, and land safely.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 448, 'prompt_tokens': 40, 'total_tokens': 488, 'completion_time': 0.537410443, 'completion_tokens_details': None, 'prompt_time': 0.001865245, 'prompt_tokens_details': None, 'queue_time': 0.047130965, 'total_time': 0.539275688}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d0655-ed42-75d1-8bce-be239568f4de-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 448, 'total_tokens': 488}),
#  AIMessage(content="Quantum computing is a new and exciting field of computer science that uses the principles of quantum mechanics to perform calculations and operations on data. It's a way of processing information that's fundamentally different from classical computing, which is based on bits (0s and 1s) and binary arithmetic.\n\nIn classical computing, information is represented as bits, which can have a value of either 0 or 1. These bits are used to perform calculations and store data in a binary format. However, as the size of the data and calculations increase, classical computers can become slow and inefficient.\n\nQuantum computing uses quantum-mechanical phenomena, such as superposition and entanglement, to perform calculations. In a quantum computer, information is represented as qubits (quantum bits), which can exist in multiple states simultaneously, known as a superposition. This means that a qubit can represent not just 0 or 1, but also any value between 0 and 1, or even multiple values at the same time.\n\nQuantum computers also use entanglement, a phenomenon where two or more qubits become connected in such a way that the state of one qubit is dependent on the state of the other. This allows quantum computers to perform calculations on multiple qubits simultaneously, which can lead to exponential speedup over classical computers for certain types of problems.\n\nQuantum computing has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve with classical computers. Some examples of problems that can be solved using quantum computing include:\n\n1. Simulating complex systems: Quantum computers can simulate the behavior of molecules, materials, and other complex systems, which can lead to breakthroughs in fields such as chemistry and materials science.\n2. Factoring large numbers: Quantum computers can factor large numbers much faster than classical computers, which has implications for cryptography and cybersecurity.\n3. Optimization problems: Quantum computers can solve optimization problems, such as finding the shortest path between two points in a complex network, much faster than classical computers.\n4. Machine learning: Quantum computers can be used to speed up certain machine learning algorithms, such as k-means clustering and support vector machines.\n\nHowever, quantum computing is still a relatively new and developing field, and there are many challenges to overcome before it becomes widely available and practical. Some of the challenges include:\n\n1. Scalability: Currently, quantum computers are small-scale and can only perform a limited number of operations before the qubits become decoherent (lose their quantum properties).\n2. Error correction: Quantum computers are prone to errors due to the fragile nature of qubits, which can be corrected using error correction codes.\n3. Control and calibration: Quantum computers require precise control and calibration of the qubits and the quantum gates used to manipulate them.\n4. Quantum noise: Quantum computers are susceptible to noise and interference from the environment, which can cause errors and decoherence.\n\nDespite these challenges, researchers and companies are actively working on developing quantum computing technology, and there are already some quantum computers available for commercial use. However, it's likely to be several years or even decades before quantum computing becomes widely available and practical.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 641, 'prompt_tokens': 40, 'total_tokens': 681, 'completion_time': 0.816116433, 'completion_tokens_details': None, 'prompt_time': 0.001832615, 'prompt_tokens_details': None, 'queue_time': 0.046733325, 'total_time': 0.817949048}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq ...
