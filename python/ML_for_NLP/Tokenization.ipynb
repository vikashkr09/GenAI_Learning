# %% [markdown]
# Tokenization

# %%
pip install NLTK
# Out:
# Collecting NLTK
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in c:\users\vikashmahato\udemy learning\python\venv\lib\site-packages (from NLTK) (8.3.1)
# Requirement already satisfied: joblib in c:\users\vikashmahato\udemy learning\python\venv\lib\site-packages (from NLTK) (1.5.3)
# Collecting regex>=2021.8.3 (from NLTK)
#   Downloading regex-2026.1.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from NLTK)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\vikashmahato\udemy learning\python\venv\lib\site-packages (from click->NLTK) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 4.7 MB/s  0:00:00
# Downloading regex-2026.1.15-cp312-cp312-win_amd64.whl (277 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, NLTK
#
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [regex]
#    ------------- -------------------------- 1/3 [regex]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    -------------------------- ------------- 2/3 [NLTK]
#    ---------------------------------------- 3/3 [NLTK]
#
# Successfully installed NLTK-3.9.2 regex-2026.1.15 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\VikashMahato\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\VikashMahato\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
corpus="""Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
sent_tokenize(corpus)
# Out:
# ["Hello Welcome,to Krish Naik's NLP Tutorials.",
#  'Please do watch the entire course!',
#  'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer  = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
